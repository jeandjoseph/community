# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
notebookutils.help()
# Out:
# StatementMeta(, b83f851c-329a-4189-bf39-33cc15a91f65, 4, Finished, Available, Finished)
# ...

# %%
notebookutils.fs.help()
# Out:
# StatementMeta(, b83f851c-329a-4189-bf39-33cc15a91f65, 5, Finished, Available, Finished)
# <b> notebookutils.fs </b> provides utilities for working with various FileSystems. <br/><br/>
# Below is overview about the available methods: <br/><br/>
# <b> cp(from: String, to: String, recurse: Boolean = false): Boolean </b>
# -> Copies a file or directory, possibly across FileSystems <br/>
# <b> fastcp(from: String, to: String, recurse: Boolean = true): Boolean </b>
# -> Copies a file or directory via azcopy, possibly across FileSystems. <br/>
# <b> mv(from: String, to: String, createPath: Boolean = false,
# overwrite: Boolean = false): Boolean </b>
# -> Moves a file or directory, possibly across FileSystems <br/>
# <b> ls(dir: String): Array </b>
# -> Lists the contents of a directory <br/>
# <b> mkdirs(dir: String): Boolean </b>
# -> Creates the given directory if it does not exist, also creating any
# necessary parent directories <br/>
# ...

# %%
#notebookutils.fs.ls("Files")
notebookutils.fs.ls("Files")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 4, Finished, Available, Finished)
# [FileInfo(path=abfss://5cab46c1-4712-485c-a5a3-934b642f3f21@onelake.dfs.fabric.microsoft.com/138bbc1b-d002-46c8-bead-4f950965f0c0/Files/csv, name=csv, size=0)]

# %%
notebookutils.fs.mkdirs("Files/dp700")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 5, Finished, Available, Finished)
# True

# %%
notebookutils.fs.rm("Files/dp700")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 6, Finished, Available, Finished)
# True

# %%
notebookutils.fs.ls("abfss://demofiles@azdlstrg.dfs.core.windows.net/csv/Products/InitialLoad/Products.csv")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 20, Finished, Available, Finished)
# [FileInfo(path=abfss://demofiles@azdlstrg.dfs.core.windows.net/csv/Products/InitialLoad/Products.csv, name=Products.csv, size=566)]

# %%
notebookutils.fs.head("abfss://demofiles@azdlstrg.dfs.core.windows.net/csv/Products/InitialLoad/Products.csv")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 21, Finished, Available, Finished)
# 'ProductId,Type,SKU,Name,Size,IsInStock,TransactionDate\r\n101,Electronics,SKU101,Smartphone M1,Medium,1,2025-08-01\r\n102,Electronics,SKU102,Laptop X2,Large,1,2025-08-02\r\n103,Apparel,SKU103,T-Shirt Classic,Small,1,2025-08-03\r\n104,Apparel,SKU104,Jeans Slim,Medium,1,2025-08-04\r\n105,Home,SKU105,Blender Pro,Small,1,2025-08-05\r\n106,Home,SKU106,Vacuum Max,Large,1,2025-08-06\r\n107,Toys,SKU107,Drone Mini,Small,1,2025-08-07\r\n108,Toys,SKU108,RC Car Turbo,Medium,1,2025-08-08\r\n109,Beauty,SKU109,Lipstick Red,Small,1,2025-08-09\r\n110,Beauty,SKU110,Perfume Luxe,Medium,1,2025-08-10'

# %%
mssparkutils.fs.cp("abfss://demofiles@azdlstrg.dfs.core.windows.net/csv/Products/InitialLoad/Products.csv",
    "Files/csv/")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 15, Finished, Available, Finished)
# True

# %%
# Example using ABFS (Azure Data Lake Gen2)
notebookutils.fs.cp(
    "abfss://demofiles@azdlstrg.dfs.core.windows.net/csv/Products/",
    "Files/csv/",
    recurse=True
)
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 11, Finished, Available, Finished)
# True

# %%
notebookutils.notebook.help()
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 22, Finished, Available, Finished)
# The notebook module. <br/><br/>
# <b> exit(value: String): void </b> ->
# This method lets you exit a notebook with a value. <br/>
# <b> run(path: String, timeoutSeconds: int, arguments: Map, workspace: String): String </b>
# -> This method runs a notebook and returns its exit value. <br/><br/>
# <b> runMultiple(DAG: Any): Map[String, MsNotebookRunResult] </b>
# -> Runs multiple notebooks concurrently with support for dependency relationships.
# <br/>
# <b> validateDAG(DAG: Any): Boolean </b>
# -> This method check if the DAG is correctly defined. <br/><br/>
# <displayInFabric>
# <b> create(name: String, description: String = "", content: String = "",
#  defaultLakehouse: String = "", defaultLakehouseWorkspace: String = "",
#  workspaceId: String = ""): Artifact </b>
# -> Create a new Notebook. <br/>
# <b> get(name: String, workspaceId: String = ""): Artifact </b>
# ...

# %%
notebookutils.notebook.help("exit")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 24, Finished, Available, Finished)
# /** <br/>
# * This method lets you exit a notebook with a value. <br/>
# * <br/>
# * @param value the value to return when exiting <br/>
# */ <br/><b>exit(value: String): Unit</b><br/><br/><a target="_blank" href="https://learn.microsoft.com/en-us/fabric/data-engineering/notebook-utilities">Learn more</a>

# %%
notebookutils.notebook.exit("this is a test")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 25, Finished, Available, Finished)
# ExitValue: this is a test

# %%
notebookutils.notebook.help("run")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 26, Finished, Available, Finished)
# /** <br/>
# * This method runs a notebook and returns its exit value. The notebook will run <br/>
# * in the current livy session context by default. <br/>
# * <br/>
# * @param path absolute path to the notebook, e.g. /path/to/notebook <br/>
# * @param timeoutSeconds timeout in seconds for the called notebook. If the run failed <br/>
# * to finish within this time, this method will throw an exception. <br/>
# * @param arguments string map of arguments to pass to the notebook <br/>
# * @param workspace the workspace to run the notebook in, support workspace name
# or workspace id. If not specified, use current workspace. <br/>
# * <br/>
# * @return the string returned by msutils.notebook.exit() or null <br/>
# * @throws NotebookExecutionException if the notebook run did not complete successfully <br/>
# */ <br/><b>run(
# path: String,
# timeoutSeconds: Int = 90,
# ...

# %%
exit_value = notebookutils.notebook.run("notebook-demo-exit-value",60,{"param":"Just For Demo Purpose"})
print(exit_value)
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 28, Finished, Available, Finished)
# notebook-demo-exit-value, it works

# %%
notebookutils.notebook.help("runMultiple")
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 29, Finished, Available, Finished)
# /** <br/>
# * Runs multiple notebooks concurrently with support for dependency relationships. <br/>
# * <br/>
# * @param DAG A list of notebook names or a complex data structure
#  (dict or JSON string) that meets the requirements of the
#   com.microsoft.spark.notebook.msutils.impl.MsNotebookPipeline scala class. <br/>
#   And you can use @activity('your activity name').exitValue() in args
#   to get the exit value of the dependency activity. <br/>
# * @param config: Configuration for the display DAG graph, only supported in python <br/>
# * Keys include: displayDAGViaGraphviz, showArgs, showTime<br/>
#   for example: {"displayDAGViaGraphviz": True}<br/>
#   displayDAGViaGraphviz: whether to display DAG graph via graphviz, default to False<br/>
#   showArgs: whether to show args in DAG graph, default to False<br/>
#   showTime: whether to show time in DAG graph, default to False<br/>
# ...

# %%
notebookutils.notebook.runMultiple(["nb-demo-runMultiple-01","nb-demo-runMultiple-02"])
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 31, Finished, Available, Finished)
# {'0': {'exitVal': 'nb-demo-runMultiple-01', 'exception': None},
#  '1': {'exitVal': 'nb-demo-runMultiple-02', 'exception': None}}

# %%
# run multiple notebooks with parameters
from graphviz import Digraph

DAG = {
    "activities": [
        {
            "name": "nb-demo-runMultiple-01",  # activity name, must be unique
            "path": "nb-demo-runMultiple-01",  # notebook path
            "timeoutPerCellInSeconds": 60,          # max timeout for each cell, default to 90 seconds
            "retry": 1,                             # retry amount
            "retryIntervalInSeconds": 10,           # retry interval in seconds
            "args": {"param1": "Hello World!"}      # notebook parameters
        },
        {
            "name": "nb-demo-runMultiple-02",
            "path": "nb-demo-runMultiple-02"
        },
        {
            "name": "nb-demo-runMultiple-03",
            "path": "nb-demo-runMultiple-03",
            "timeoutPerCellInSeconds": 120,
            "dependencies": ["nb-demo-runMultiple-02"]  # list of activity names that this activity depends on
        }
    ],
    "timeoutInSeconds": 43200,  # max timeout for the entire pipeline, default to 12 hours
    "concurrency": 50           # max number of notebooks to run concurrently, default to 50, 0 means unlimited
}
notebookutils.notebook.runMultiple(DAG,{"displayDAGViaGraphviz":True})
# Out:
# StatementMeta(, 3349fe99-b77a-4092-88ce-9084dcb8d92b, 37, Finished, Available, Finished)
# {'nb-demo-runMultiple-01': {'exitVal': 'nb-demo-runMultiple-01',
#   'exception': None},
#  'nb-demo-runMultiple-02': {'exitVal': 'nb-demo-runMultiple-02',
#   'exception': None},
#  'nb-demo-runMultiple-03': {'exitVal': 'nb-demo-runMultiple-03',
#   'exception': None}}
